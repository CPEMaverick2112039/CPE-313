# %% [markdown]
# Maverick P. Rojo CPE32S8 Image taker

# %%
import cv2
import os

def detect(folder_path):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

    camera = cv2.VideoCapture(0)

    i = 100  # Counter for saving images

    while True:
        ret, frame = camera.read()
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        for (x, y, w, h) in faces:
            img = cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

            roi_gray = gray[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray, 1.03, 5, 0, (40, 40))

            # Save the detected face region with a descriptive filename:
            face_filename = f"detected_face_{i}.jpg"
            face_path = os.path.join(folder_path, face_filename)
            cv2.imwrite(face_path, roi_gray)
            i += 1

            # Display the frame with detected faces and eye rectangles:
            cv2.imshow("camera", frame)

        if cv2.waitKey(1000 // 12) & 0xff == ord("q"):
            break

    camera.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Specify the folder path where you want to save detected faces:
    folder_path = r'Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\happy'
    detect(folder_path)

# %% [markdown]
# WITH IMAGE TRACKER (COUNT):

# %%
import cv2
import os

def detect(folder_path):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

    camera = cv2.VideoCapture(0)

    i = 1  # Counter for saving images

    while True:
        ret, frame = camera.read()
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        for (x, y, w, h) in faces:
            img = cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

            roi_gray = gray[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray, 1.03, 5, 0, (40, 40))

            # Save the detected face region with a descriptive filename:
            face_filename = f"detected_face_{i}.jpg"
            face_path = os.path.join(folder_path, face_filename)
            
            try:
                # Ensure the directory exists before saving
                os.makedirs(folder_path, exist_ok=True)
                # Save the image
                cv2.imwrite(face_path, roi_gray)
                print(f"Saved image: {face_path}")
            except Exception as e:
                print(f"Error saving image: {str(e)}")

            i += 1

            # Display the frame with detected faces and eye rectangles:
            cv2.imshow("camera", frame)

        if cv2.waitKey(1000 // 12) & 0xff == ord("q"):
            break

    camera.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Specify the folder path where you want to save detected faces:
    folder_path = r'D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry'
    detect(folder_path)
# Out:
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_1.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_2.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_3.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_4.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_5.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_6.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_7.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_8.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_9.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_10.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_11.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_12.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_13.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_14.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_15.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_16.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_17.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_18.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_19.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_20.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_21.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_22.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_23.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_24.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_25.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_26.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_27.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_28.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_29.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_30.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_31.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_32.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_33.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_34.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_35.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_36.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_37.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_38.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_39.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_40.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_41.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_42.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_43.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_44.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_45.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_46.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_47.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_48.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_49.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_50.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_51.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_52.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_53.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_54.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_55.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_56.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_57.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_58.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_59.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_60.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_61.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_62.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_63.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_64.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_65.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_66.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_67.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_68.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_69.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_70.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_71.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_72.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_73.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_74.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_75.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_76.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_77.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_78.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_79.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_80.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_81.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_82.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_83.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_84.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_85.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_86.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_87.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_88.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_89.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_90.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_91.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_92.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_93.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_94.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_95.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_96.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_97.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_98.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_99.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_100.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_101.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_102.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_103.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_104.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_105.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_106.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_107.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_108.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_109.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_110.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_111.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_112.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_113.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_114.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_115.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_116.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_117.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_118.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_119.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_120.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_121.jpg
# Saved image: D:\Advanced machine learning and Deep learning\Assignment 4.1 Mood detection\pictures\angry\detected_face_122.jpg
